# %% [markdown]
# # Library import

# %%
import os
from PIL import Image
from torch.utils.data import Dataset
import torch.utils.data as data
from torchvision import datasets, transforms, utils
import torch
from torchvision.utils import save_image
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import wandb

from sklearn.metrics import confusion_matrix, recall_score, precision_score, f1_score

import warnings
warnings.filterwarnings('ignore')

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"device = {device}")
# Out:
# device = cuda

# %% [markdown]
# # Hyperparameters

# %%
model_name = "first_architecture"
eval_every = 5
save_every = 5

# est-ce qu'on pourrait pas faire des batch size différent pour le train et le test/validation ?
# as-tu d'autres idée d'hyperparametre ?
batch_size = 32
learning_rate = 0.001
nb_epochs = 10


# if ask for a key, COPY/PASTE bc0dc5f66039bf86ffba73188a299faed907973c
wandb.init(
    project="deep_learning_project", 
    config = {
        "model": model_name,
        "batch_size": batch_size,
        "learning_rate": learning_rate,
        "nb_epochs": nb_epochs,
        "eval_every": eval_every,
        "save_every": save_every,
    },
    name=model_name,
)
# Out:
# wandb version 0.16.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/home/jwalraff/DeepWalraff/project/wandb/run-20240409_130729-pa9zc0uh</code>
# Syncing run <strong><a href='https://wandb.ai/data-science-project/deep_learning_project/runs/pa9zc0uh' target="_blank">first_architecture</a></strong> to <a href='https://wandb.ai/data-science-project/deep_learning_project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/data-science-project/deep_learning_project' target="_blank">https://wandb.ai/data-science-project/deep_learning_project</a>
#  View run at <a href='https://wandb.ai/data-science-project/deep_learning_project/runs/pa9zc0uh' target="_blank">https://wandb.ai/data-science-project/deep_learning_project/runs/pa9zc0uh</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/data-science-project/deep_learning_project/runs/pa9zc0uh?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
# wandb.finish()
# Out:
# VBox(children=(Label(value='0.004 MB of 0.018 MB uploaded\r'), FloatProgress(value=0.23208009372670146, max=1.…

# %% [markdown]
# # Dataset import

# %%
print(os.getcwd())
os.chdir("/scratch/users/jwalraff/DeepWalraff/augmented_dataset")
print(os.getcwd())
print(os.listdir(os.getcwd()))
# Out:
# /scratch/users/jwalraff/DeepWalraff
# /scratch/users/jwalraff/DeepWalraff/augmented_dataset
# ['test', 'train', 'validation']

# %%
import datasetCreation

root_dir = "/scratch/users/jwalraff/DeepWalraff/augmented_dataset"
validation_dir = os.path.join(root_dir, "validation")
categories = os.listdir(validation_dir)

transform = transforms.Compose([
    transforms.ToTensor()
])

train_loader = datasetCreation.getDataLoader(root_dir, 32, num_workers= 4, mode='train', transform=transform)
validation_loader = datasetCreation.getDataLoader(root_dir, 32, mode='validation', transform=transform)
test_loader = datasetCreation.getDataLoader(root_dir, 32, mode='test', transform=transform)

# %%
# comes from hw2
def show_images(img):
    plt.imshow(transforms.functional.to_pil_image(img), cmap='gray')
    plt.show()

# show the images from a batch
images, labels = next(iter(train_loader))
print(type(images))
show_images(utils.make_grid(images))
print(*[categories[l] for l in labels])
# Out:
# <class 'torch.Tensor'>
# sad happy sad angry sad sad angry neutral angry angry happy angry sad sad happy surprised angry fearful sad happy angry surprised angry surprised fearful happy angry sad happy angry angry happy

# %% [markdown]
# # Class Weights

# %%
# source of the formula https://www.analyticsvidhya.com/blog/2020/10/improve-class-imbalance-class-weights/
weights = []
category_count = []
n_category = len(categories)

for i, cat in enumerate(categories):
    tmp = os.path.join(validation_dir, cat)
    category_count.append(len(os.listdir(tmp)))

n_sample = sum(category_count)    
    
for i, n_sample_i in enumerate(category_count):
    weights.append(n_sample/(n_category*n_sample_i))

weights = torch.tensor(weights, dtype=torch.float).to(device)
weights
# Out:
# tensor([1.0181, 9.2435, 1.0042, 0.5676, 0.8275, 0.8509, 1.3015],
#        device='cuda:0')

# %% [markdown]
# # Model

# %%
class ConvNet(nn.Module):
    def __init__(self):
        # basic architecture from slide 35/59 lecture 6 of deep learning course
        # INPUT → [[CONV → ReLU]*N → POOL?]*M → [FC → ReLU]*K → FC
        super(ConvNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, 1)
        self.conv2 = nn.Conv2d(32, 64, 3, 1)
        self.fc1 = nn.Linear(64*73*73, 1024) # aucune idée de si c'est juste (merci copilot, apres avec un run, je saurais change ceci) (pour le 64*73*73)
        self.fc2 = nn.Linear(1024, 1024)
        self.fc3 = nn.Linear(1024, 7)
        self.drop = nn.Dropout(0.2)

    def forward(self, x):
        print(f"x shape initially: {x.shape}")
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        print(f"x shape after first maxpool: {x.shape}")
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        print(f"x shape after second maxpool: {x.shape}")
        x = x.view(-1, 64*73*73) # pareil ici (pour le 64*73*73)
        print(f"x shape after flatten {x.shape}")
        x = F.relu(self.fc1(x))
        x = self.drop(x)
        x = F.relu(self.fc2(x))
        x = self.drop(x)
        x = self.fc3(x)
        return x

# %%
convnet = ConvNet()
convnet.train()

print(f"convnet architecture: \n{convnet}")

# from https://saturncloud.io/blog/check-the-total-number-of-parameters-in-a-pytorch-model/#:~:text=To%20check%20the%20number%20of%20parameters%20in%20a%20PyTorch%20model,its%20total%20number%20of%20elements
print(f"\n numbers of parameters: {sum(p.numel() for p in convnet.parameters())}")

# Loss and optimizer
criterion = nn.CrossEntropyLoss(reduction='none')
optimizer = torch.optim.Adam(convnet.parameters(), lr=learning_rate)
# Out:
# convnet architecture:
# ConvNet(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=341056, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#   (fc3): Linear(in_features=1024, out_features=7, bias=True)
#   (drop): Dropout(p=0.2, inplace=False)
# )
#
#  numbers of parameters: 350317959

# %% [markdown]
# # Training

# %% [markdown]
# Faut-il rajouter plus de truc dans wandb.log ?

# %%
def train_cnn(num_epochs):
    train_avg_loss = []
    validation_avg_loss = []
    validation_accuracy = []

    # transfer cnn to GPU (in-place)
    convnet.to(device)

    print("Entering epoch loops.....")
    for i in range(num_epochs):
        train_losses = []
        validation_losses = []
        recall_scores = []
        precision_scores = []
        f1_scores = []
        
        print("Entering train loop....")
        for x, y in train_loader:
            x = x.to(device)
            y = y.to(device)
            pred = convnet(x)
            print(f"pred shape: {pred.shape}")
            loss = criterion(pred, y)
            sample_weight = weights[y.data.view(-1).long()].view_as(y)
            loss = (loss * sample_weight).mean()

            wandb.log({
                "epoch": i, 
                "train_loss": loss
            })

            train_losses.append(loss.cpu().detach())

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        train_loss_mean = np.array(train_losses).mean()
        train_avg_loss.append(train_loss_mean)

        # à modifier en fonction du nb d'epoch qu'on met
        if i % eval_every == 0:
            print("Entering validation.....")
            with torch.no_grad():
                correct = 0

                # list because we wan't evaluate on each batch (some labels might not be in a batch)
                true_labels = torch.tensor([])
                pred_labels = torch.tensor([])
                
                for x, y in validation_loader:
                    x = x.to(device)
                    y = y.to(device)

                    pred = convnet(x)
                    loss = criterion(pred, y)
                    
                    sample_weight = weights[y.data.view(-1).long()].view_as(y)
                    loss = (loss * sample_weight).mean()

                    wandb.log({
                        "epoch": i, 
                        "validation_loss": loss
                    })

                    validation_losses.append(loss.cpu().detach())

                    y_pred = pred.argmax(dim=-1)
                    correct = correct + (y_pred == y).sum()

                    true_labels = torch.cat((true_labels, y.cpu()))
                    pred_labels = torch.cat((pred_labels, y_pred.cpu()))

                recall_scores.append(recall_score(true_labels, pred_labels, average='weighted'))
                precision_scores.append(precision_score(true_labels, pred_labels, average='weighted'))
                f1_scores.append(f1_score(true_labels, pred_labels, average='weighted'))

                validation_avg_loss.append(np.array(validation_losses).mean())
                accuracy = correct / (len(validation_loader)*batch_size)
                validation_accuracy.append(accuracy)

        print(f"Epoch {i}: train_loss = {train_loss_mean}")
        print("************************************")
        print()

        if i % save_every == 0:
            torch.save(convnet.state_dict(), f"model_intermediate/convnet_{i}.pt")

    train_avg_loss = np.array(train_avg_loss)
    validation_avg_loss = np.array(validation_avg_loss)

    torch.save(convnet.state_dict(), f"model_finished/convnet__finished_{num_epochs}.pt")

    return train_avg_loss, validation_avg_loss, validation_accuracy, recall_scores, precision_scores, f1_scores

# %%
train_avg_loss, validation_avg_loss, validation_accuracy, recall_scores, precision_scores, f1_scores = train_cnn(nb_epochs)
# Out:
# Entering epoch loops.....
# Entering train loop....
# x train loader= torch.Size([32, 1, 300, 300])
# x shape initially: torch.Size([32, 1, 300, 300])
# x shape after first maxpool: torch.Size([32, 32, 149, 149])
# x shape after second maxpool: torch.Size([32, 64, 73, 73])
# x shape after flatten torch.Size([32, 341056])
# x shape final nn: torch.Size([32, 7])
# pred shape: torch.Size([32, 7])
# x train loader= torch.Size([32, 1, 300, 300])
# x shape initially: torch.Size([32, 1, 300, 300])
# x shape after first maxpool: torch.Size([32, 32, 149, 149])
# x shape after second maxpool: torch.Size([32, 64, 73, 73])
# x shape after flatten torch.Size([32, 341056])
# x shape final nn: torch.Size([32, 7])
# pred shape: torch.Size([32, 7])
# x train loader= torch.Size([32, 1, 300, 300])
# x shape initially: torch.Size([32, 1, 300, 300])
# x shape after first maxpool: torch.Size([32, 32, 149, 149])
# x shape after second maxpool: torch.Size([32, 64, 73, 73])
# x shape after flatten torch.Size([32, 341056])
# x shape final nn: torch.Size([32, 7])
# pred shape: torch.Size([32, 7])
# x train loader= torch.Size([32, 1, 300, 300])
# x shape initially: torch.Size([32, 1, 300, 300])
# x shape after first maxpool: torch.Size([32, 32, 149, 149])
# x shape after second maxpool: torch.Size([32, 64, 73, 73])
# x shape after flatten torch.Size([32, 341056])
# x shape final nn: torch.Size([32, 7])
# pred shape: torch.Size([32, 7])
# x train loader= torch.Size([32, 1, 300, 300])
# x shape initially: torch.Size([32, 1, 300, 300])
# x shape after first maxpool: torch.Size([32, 32, 149, 149])
# x shape after second maxpool: torch.Size([32, 64, 73, 73])
# x shape after flatten torch.Size([32, 341056])
# x shape final nn: torch.Size([32, 7])
# pred shape: torch.Size([32, 7])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 train_avg_loss, validation_avg_loss, validation_accuracy, recall_scores, precision_scores, f1_scores = train_cnn(nb_epochs)
#
# Cell In[15], line 28, in train_cnn(num_epochs)
#      25 sample_weight = weights[y.data.view(-1).long()].view_as(y)
#      26 loss = (loss * sample_weight).mean()
# ---> 28 wandb.log({
#      29     "epoch": i,
#      30     "train_loss": loss
#      31 })
#      33 train_losses.append(loss.cpu().detach())
#      35 optimizer.zero_grad()
#
# File ~/anaconda3/envs/deep/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:420, in _run_decorator._noop.<locals>.wrapper(self, *args, **kwargs)
#     417         wandb.termwarn(message, repeat=False)
#     418         return cls.Dummy()
# --> 420 return func(self, *args, **kwargs)
#
# File ~/anaconda3/envs/deep/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:371, in _run_decorator._noop_on_finish.<locals>.decorator_fn.<locals>.wrapper_fn(self, *args, **kwargs)
#     368 @functools.wraps(func)
#     369 def wrapper_fn(self: Type["Run"], *args: Any, **kwargs: Any) -> Any:
#     370     if not getattr(self, "_is_finished", False):
# --> 371         return func(self, *args, **kwargs)
#     373     default_message = (
#     374         f"Run ({self.id}) is finished. The call to `{func.__name__}` will be ignored. "
#     375         f"Please make sure that you are using an active run."
#     376     )
#     377     resolved_message = message or default_message
#
# File ~/anaconda3/envs/deep/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:361, in _run_decorator._attach.<locals>.wrapper(self, *args, **kwargs)
#     359         raise e
#     360     cls._is_attaching = ""
# --> 361 return func(self, *args, **kwargs)
#
# File ~/anaconda3/envs/deep/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:1828, in Run.log(self, data, step, commit, sync)
#    1821 if self._settings._shared and step is not None:
#    1822     wandb.termwarn(
#    1823         "In shared mode, the use of `wandb.log` with the step argument is not supported "
#    1824         f"and will be ignored. Please refer to {wburls.get('wandb_define_metric')} "
#    1825         "on how to customize your x-axis.",
#    1826         repeat=False,
#    1827     )
# -> 1828 self._log(data=data, step=step, commit=commit)
#
# File ~/anaconda3/envs/deep/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:1596, in Run._log(self, data, step, commit)
#    1593 if any(not isinstance(key, str) for key in data.keys()):
#    1594     raise ValueError("Key values passed to `wandb.log` must be strings.")
# -> 1596 self._partial_history_callback(data, step, commit)
#    1598 if step is not None:
#    1599     if os.getpid() != self._init_pid or self._is_attached:
#
# File ~/anaconda3/envs/deep/lib/python3.11/site-packages/wandb/sdk/wandb_run.py:1468, in Run._partial_history_callback(self, row, step, commit)
#    1465 if self._backend and self._backend.interface:
#    1466     not_using_tensorboard = len(wandb.patched["tensorboard"]) == 0
# -> 1468     self._backend.interface.publish_partial_history(
#    1469         row,
#    1470         user_step=self._step,
#    1471         step=step,
#    1472         flush=commit,
#    1473         publish_step=not_using_tensorboard,
#    1474     )
#
# File ~/anaconda3/envs/deep/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:573, in InterfaceBase.publish_partial_history(self, data, user_step, step, flush, publish_step, run)
#     571     item = partial_history.item.add()
#     572     item.key = k
# --> 573     item.value_json = json_dumps_safer_history(v)
#     575 if publish_step and step is not None:
#     576     partial_history.step.num = step
#
# File ~/anaconda3/envs/deep/lib/python3.11/site-packages/wandb/util.py:842, in json_dumps_safer_history(obj, **kwargs)
#     840 def json_dumps_safer_history(obj: Any, **kwargs: Any) -> str:
#     841     """Convert obj to json, with some extra encodable types, including histograms."""
# --> 842     return dumps(obj, cls=WandBHistoryJSONEncoder, **kwargs)
#
# File ~/anaconda3/envs/deep/lib/python3.11/json/__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File ~/anaconda3/envs/deep/lib/python3.11/json/encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File ~/anaconda3/envs/deep/lib/python3.11/json/encoder.py:258, in JSONEncoder.iterencode(self, o, _one_shot)
#     253 else:
#     254     _iterencode = _make_iterencode(
#     255         markers, self.default, _encoder, self.indent, floatstr,
#     256         self.key_separator, self.item_separator, self.sort_keys,
#     257         self.skipkeys, _one_shot)
# --> 258 return _iterencode(o, 0)
#
# File ~/anaconda3/envs/deep/lib/python3.11/site-packages/wandb/util.py:803, in WandBHistoryJSONEncoder.default(self, obj)
#     802 def default(self, obj: Any) -> Any:
# --> 803     obj, converted = json_friendly(obj)
#     804     obj, compressed = maybe_compress_history(obj)
#     805     if converted:
#
# File ~/anaconda3/envs/deep/lib/python3.11/site-packages/wandb/util.py:615, in json_friendly(obj)
#     613         obj = obj.cpu().detach().numpy()
#     614     else:
# --> 615         return obj.item(), True
#     616 elif is_jax_tensor_typename(typename):
#     617     obj = get_jax_tensor(obj)
#
# KeyboardInterrupt:

# %%
plt.figure(figsize = (10, 6))

plt.plot(train_avg_loss, label='train loss')
plt.plot(validation_avg_loss, label='validation loss')

plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend()
plt.show()
